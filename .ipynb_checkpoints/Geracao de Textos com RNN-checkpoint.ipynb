# %%
import torch
import string
import random
import re
import time, math

import torch
import torch.nn as nn
from torch.autograd import Variable

from requests import get
import re

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
# Ler um arquivo em texto puro contendo o conteúdo a ser aprendido
file = get('https://raw.githubusercontent.com/ArthurSiqueiraS/RNN-LSTM/master/lfv_texts_plain.txt?token=AHJJ64SA2ARVW2EF47KFBIK5AXELI').text

symbols = ['\n',' ',',','.','!','?','*','(',')','"',':','…','―','@','$','%', "”", "“"]
for symbol in symbols:
  file = file.replace(symbol, " " + symbol + " ")

file = file.split(" ")
file = list(filter(lambda w: w != '' or w == '\n', file))

file_len = len(file)
print('file_len =', file_len)

all_words = list(set(file))
n_words = len(all_words)
print(all_words, n_words)
# Out:
# file_len = 277556
# ['Cometa', 'fila', 'perguntarem', 'cuidasse', 'terminantemente', 'nascidos', 'Portuguesa', 'barcos', 'travessa', 'resgate', 'Larguei', 'bau-', 'terrena', 'troianos', 'Papa', 'reunião', 'Praga', 'mirados', 'Chicago', 'iluminada', 'previsíveis', 'compotas', 'meus', 'Olaria', 'Mantenho', 'Assumo', 'assustador', 'vovô', 'resumirei', 'coletada', 'Úmida', 'antegozando', 'umbigo', 'Caetano', 'mastigar', 'previsão', 'correntes', 'durariam', 'abotoam', 'gritarem', 'logarítmos', 'escroques', 'monsieur', 'Diabo', 'cenas', 'tarol', 'enigma', 'lâminas', 'compromisso', 'iguala', 'majestade', 'papéis', 'esvoaçantes', 'charada', 'Elas', 'Amores', 'arrancar', 'fração', 'publicada', 'italiano', 'contos', '‘Jacuzzi’', 'irá', 'repórteres', 'Beat', 'concebe', 'terças-feiras', 'servira', 'causado', 'reflexivo', 'salientes', 'quê', 'paga', 'debruçou', 'provocação', 'ajudá-lo', 'crie', 'irregular', 'deveria', 'assessoria', 'inconveniência', 'desvendaram', 'Natureza', 'herói', 'emociono', 'Junho', 'conceber', 'Pretos', 'relativo', 'considerasse', 'ilustrativo', 'pontapé', 'presenteia', 'exigiram', 'métodos', 'assinaram', 'riso', 'seduzir', 'arrombamos', 'Manera', 'veículos', 'Amante', 'levantado', 'vastidão', 'máscara', 'periga', '150', 'Alexandria', 'tocá-la', 'discursos', 'favorito', 'sérios', 'sofriam', 'Redor', 'receptores', 'Telê', 'clavícula', 'tentaculares', 'coquille', 'querido', 'camada', 'princípio', 'Antigamente', 'acusação', 'desconhecidos', 'brincos', 'paciente', 'entrada', 'autocontrole', 'aphrós', 'Oba', 'instruí-lo', 'beneficente', 'morrerão', 'primeiros-socorros', 'casarão', 'tivesse', 'turismo', 'garantiam', 'custo', 'Dusinha', 'encontrar', 'expressando', 'Ge', 'explicasse', 'Carinhoso', 'sorvetes', 'determinou', 'vexado', 'imitam', 'louro', 'histórico', 'achava', 'perfumar', 'Preferiria', 'contingência', 'escorregou', 'ameba', 'treinadores', 'cantoras', 'igualzinho', 'tropa', 'saem', 'continue', 'sebo', 'Companhia', 'fortuito', 'Corinha', 'Noemia', 'Nasciam', 'microfones', 'complementava', 'espaço', 'imite', 'Românticos', 'hipotética', 'Faz', 'matagal', 'antiácido', 'misérias', 'Recuperar', 'vocês', 'sem-nada', 'mexendo', 'advento', 'Joga-se', 'alemão', 'vegetale', 'assados', 'flamenco', 'danada', 'perguntara', 'Bel', 'presenteada', 'náufrago', 'Plúmbeo', 'decoração', 'perderem', 'brinquedo', 'kit', 'prostraram', 'profissionalizar', 'respira', 'pepino', 'sucumbindo', 'vinha', 'harém', 'patrão', 'Atirou-se', 'agarrada', 'abanando-as', 'atletas', 'cure-', 'circunstâncias', 'bem-intencionada', 'Suco', 'deitar', 'esperando', 'sabonete', 'chama', 'trabalhamos', 'terminam', 'recusando', 'divina', 'alternativas', 'fazermos', 'secretaria', 'nitidez', 'telhado', 'tarefa', 'Cuidado', 'despedir', 'respingou', 'Passariam', 'traste', 'Bailarina', 'rumo', 'engoliu', 'afastou-se', 'gregas', 'Meleca', 'mostrou', 'Documentos', 'íntimos', 'sacudiriam', 'acalmada', 'Boca', 'pinta', 'voadores', '21', 'ideia', 'sabeis', 'conserto', 'adotaram', 'dissesse', 'interrompê-lo', 'arcaico', 'eliminavam', 'ação', 'Seda', 'precocidade', 'finalmente', 'simétrica', 'Patrícia', 'situações', 'cancelar', 'influenciou', 'sobreviveu', 'compradas', 'Estejam', 'Ricardo', 'asilo', 'denunciá-lo', 'revolta', 'entressafra', 'Incentivamos', 'autopreservação', 'gastroenterologistas', 'xingando', 'aniquilando', 'registrados', 'Fast', 'revolucionaria', 'quadrada', 'imperadora', 'vulcânicas', 'trotskista', 'vestiários', 'fêmea', 'inundação', 'vilão', 'indefensável', 'delegado', 'Paraty', 'impor', 'extremo', 'pavões', 'mosquitos', 'reconhecê-la', 'adotou', 'janelinha', 'prometera', 'ladrão', 'estudada', 'escocês', 'saldada', 'virão', 'estabeleceria', 'Convencendo-o', 'traindo', 'Esqueceremos', 'posicionamento', 'soco', 'Mesmo', 'prudente', 'convencê-los', 'quina', 'internacionais', 'retidão', 'viúvos', 'necessidades', 'pássaro', 'Guadalajara', 'facas', 'Oswaldo', 'decidirem', 'desestimula', 'conferem', 'estávamos', 'esco ...
# 25193

# %%
chunk_len = 30

# Gera um pedaço aleatório de texto com o tamanho especificado em chuck_len
def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# ['que', 'nos', 'leva', 'a', 'imaginar', 'como', 'seria', ',', 'ignorando-se', 'a', 'disparidade', 'cronológica', ',', 'uma', 'reunião', 'desta', 'turma', '.', 'Que', 'bem', 'poderia', 'acabar', 'com', 'o', 'papa', 'dançando', 'com', 'a', 'Gal', 'uma', 'composição']

# %%
# Converte palavras para uma lista de inteiros

def word_tensor(words):
    tensor = torch.zeros(len(words)).long()
    for i in range(len(words)):
      try:
        tensor[i] = all_words.index(words[i])
      except:
        print(i)
        raise
    return Variable(tensor)

print(word_tensor(['?', 'Caixeiro', 'extermínio']))
# Out:
# tensor([ 9679, 19337, 18984])

# %%
# Gera um 'exemplo' aleatório (um pedaço aleatório convertido para lista de inteiros)
def random_training_set(): 
    chunk = random_chunk()
    inp = word_tensor(chunk[:-1])
    target = word_tensor(chunk[1:])
    return inp, target

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
    
    def forward(self, input, hidden):
        input = self.encoder(input.view(1, -1))
        output, hidden = self.lstm(input.view(1, 1, -1), hidden)
        decoded_output = self.decoder(output.view(1, -1))
        return decoded_output, hidden

    def init_hidden(self):
        size = Variable(torch.zeros(self.n_layers, 1, self.hidden_size))
        return (size, size)

# %%
# Gera um texto iniciando com "prime_str" de tamanho "predict_len" e variação definida por "temperature"
def evaluate(prime_str=['A'], predict_len=20, temperature=0.8):
    hidden = rnn.init_hidden()
    hidden = [h.cuda() for h in hidden]
    prime_input = word_tensor(prime_str).cuda()
    predicted = prime_str
    
    # prime_str é o texto inicial que o gerado irá completar
    for p in range(len(prime_str) - 1):
        _, hidden = rnn(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = rnn(inp, hidden)
        
        # Usa a temperatura para amostrar a distribuição e escolher a saída probabilísticamente
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Adiciona o caracter predito à string de saída
        predicted_word = all_words[top_i]
        predicted.append(predicted_word)
        inp = word_tensor([predicted_word]).cuda()

    return ' '.join(predicted)

# %%
# Treina sobre um exemplo (i.e. uma amostragem do texto)

def train(inp, target):
    hidden = rnn.init_hidden()
    rnn.zero_grad()
    loss = 0

    inp = inp.cuda()
    hidden = [h.cuda() for h in hidden]
    for c in range(chunk_len):
        output, hidden = rnn(inp[c], hidden)
        loss += loss_metric(output, target[c].unsqueeze(0))

    loss.backward()
    optimizer.step()

    return loss.data.item() / chunk_len

# %%
n_epochs = 50000
print_every = 1
hidden_size = 512
n_layers = 2
lr = 0.0005

cuda = torch.device('cuda')

rnn = RNN(n_words, hidden_size, n_words, n_layers)
rnn.cuda()

optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
loss_metric = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    example = random_training_set()
    loss = train(example[0].cuda(),example[1].cuda())       
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate(['Os'], 20), '\n')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-f8d65ff4bf17> in <module>
#       8
#       9 rnn = RNN(n_words, hidden_size, n_words, n_layers)
# ---> 10 rnn.cuda()
#      11
#      12 optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in cuda(self, device)
#     263             Module: self
#     264         """
# --> 265         return self._apply(lambda t: t.cuda(device))
#     266
#     267     def cpu(self):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     191     def _apply(self, fn):
#     192         for module in self.children():
# --> 193             module._apply(fn)
#     194
#     195         for param in self._parameters.values():
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     197                 # Tensors stored in modules are graph leaves, and we don't
#     198                 # want to create copy nodes, so we have to unpack the data.
# --> 199                 param.data = fn(param.data)
#     200                 if param._grad is not None:
#     201                     param._grad.data = fn(param._grad.data)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in <lambda>(t)
#     263             Module: self
#     264         """
# --> 265         return self._apply(lambda t: t.cuda(device))
#     266
#     267     def cpu(self):
#
# RuntimeError: CUDA out of memory. Tried to allocate 50.00 MiB (GPU 0; 2.00 GiB total capacity; 1.23 GiB already allocated; 3.62 MiB free; 72.00 MiB cached)

# %%
# Com a rede treinada, gerar um texto longo

print(evaluate('O psicanalista de', 5500), '\n')
