# %%
import torch
import string
import random
import re
import time, math

import torch
import torch.nn as nn
from torch.autograd import Variable

from requests import get
import re

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
# Ler um arquivo em texto puro contendo o conteúdo a ser aprendido
symbols = "\,\.\!\?\*\)\(\"\:\..."
file = open('lfv_texts_plain.txt', encoding='utf-8').read().lower().replace('\n', ' \n ')
print(re.findall("[^]"))

file = [w for w in file.split(' ') if w.strip() != '' or w == '\n']
file_len = len(file)
print('file_len =', file_len)

all_words = list(set(file))
n_words = len(all_words)
# Out:
# de$1bc
# file_len = 234078

# %%
chunk_len = 30

# Gera um pedaço aleatório de texto com o tamanho especificado em chuck_len
def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# entado, até a ética. Aqui o p

# %%
# Converte palavras para uma lista de inteiros

def word_tensor(words):
    tensor = torch.zeros(len(words)).long()
    for w in range(len(words)):
      try:
        tensor[w] = all_words.index(words[w])
      except:
        print(w)
        raise
    return Variable(tensor)

print(word_tensor('abcDEF'))
# Out:
# tensor([ 90,  12,  44,  95,  84, 113])

# %%
# Gera um 'exemplo' aleatório (um pedaço aleatório convertido para lista de inteiros)
def random_training_set():    
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
    
    def forward(self, input, hidden):
        input = self.encoder(input.view(1, -1))
        output, hidden = self.lstm(input.view(1, 1, -1), hidden)
        decoded_output = self.decoder(output.view(1, -1))
        return decoded_output, hidden

    def init_hidden(self):
        size = Variable(torch.zeros(self.n_layers, 1, self.hidden_size))
        return (size, size)

# %%
# Gera um texto iniciando com "prime_str" de tamanho "predict_len" e variação definida por "temperature"
def evaluate(prime_str='A', predict_len=100, temperature=0.8):
    hidden = rnn.init_hidden()
    hidden = [h.cuda() for h in hidden]
    prime_input = char_tensor(prime_str).cuda()
    predicted = prime_str

    # prime_str é o texto inicial que o gerado irá completar
    for p in range(len(prime_str) - 1):
        _, hidden = rnn(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = rnn(inp, hidden)
        
        # Usa a temperatura para amostrar a distribuição e escolher a saída probabilísticamente
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Adiciona o caracter predito à string de saída
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char_tensor(predicted_char).cuda()

    return predicted

# %%
# Treina sobre um exemplo (i.e. uma amostragem do texto)

def train(inp, target):
    hidden = rnn.init_hidden()
    rnn.zero_grad()
    loss = 0

    inp = inp.cuda()
    hidden = [h.cuda() for h in hidden]
    for c in range(chunk_len):
        output, hidden = rnn(inp[c], hidden)
        loss += loss_metric(output, target[c].unsqueeze(0))

    loss.backward()
    optimizer.step()

    return loss.data.item() / chunk_len

# %%
n_epochs = 50000
print_every = 10
hidden_size = 512
n_layers = 2
lr = 0.0005

cuda = torch.device('cuda')

rnn = RNN(n_characters, hidden_size, n_characters, n_layers)
rnn.cuda()

optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
loss_metric = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    example = random_training_set()
    loss = train(example[0].cuda(),example[1].cuda())       
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate('Os', 100), '\n')
# Out:
#  2s (10 0%) 3.3638]
# Ost0dVh oo:oh erlr ee atoeso mase―ee1 ao a ce8so oeoEt́oroUoa ee ootfroe eoeniomittuodroaeooaao eosmao
#
#  5s (20 0%) 3.0726]
# Osnouus  u  dono oáoo r  i epa.egVenrd  er8o clvi car us  tncsuoo m etdene  niddrn oa o oenau ml ipu,
#
#  8s (30 0%) 2.9489]
# Ossm ante s er slce e o ́́rs̃ .  sifa sor le ̃ia  cta irev smprsarao i̧oore aa mea oeo ra d ss urlgra
#
#  10s (40 0%) 2.9948]
# Osid e cha niánla do sas ́a mip orv ãoe nmu
# fn e   ,̧ olel dda ecuao eg eo ted o ,r bea ulenntie mb g
#
#  13s (50 0%) 2.7475]
# Os -t,ora fa co cerhea co fsho o opu l̃z ese ce tumms lra depsa eento maa tmam a rqa cal o dde. o qiie
#
#  16s (60 0%) 2.8186]
# Osqles due a nera smsa ti*ppota ssranpau o os se asu arļo aas da canta rnee o se aree ma prastuicay F
#
#  19s (70 0%) 2.6516]
# Osialnsxa e
# eso ver de nas poritan ade Iâ pasanEirionuziria elo tira so atcari.iC e a acalacorais ara
#
#  21s (80 0%) 2.5587]
# Os ’eqdodo a nasa o ros fd
# le a terijem
# a pauto yuVonico ereride dilose nnto fs ceso e sesenceres euce
#
#  24s (90 0%) 2.4183]
# Os derem e ileptara cevalentonga ou ainaras aga e a damia –arso tefasentole Menram carerermar do qrran
#
#  27s (100 0%) 2.5949]
# Os o me Merom hudẽva mo. posem erizrde que te. u mo dera cadita mico u terro quivinta o á coltem nar
#
#  30s (110 0%) 2.4724]
# Os. ãa molde ointo cmameu nolraras a nos caltainetam ma e fra, or. á cá cinas "ial premir gus de mada
#
#  32s (120 0%) 2.6073]
# Os‘eu quu Foma eista e maviam eu a fom ése dide ra cos a senvistames daraá qesre. Delde do os fera qu
#
#  35s (130 0%) 2.5785]
# Os Nenestoncess dera a pema ser eiro e aratõ, uusa do, e endou. Wuesmo muntanâ quer tospe purante qu
#
#  38s (140 0%) 2.3434]
# Os fam ̂ho sino pogarrima dẽo cocre O ela
# vecessem aas oI e au au gupa, ho o a sise, deis asa. que o"
#
#  40s (150 0%) 2.3142]
# Os ̃or Sa, crius entobrar do a a dia de ima ara dado turo pamo secrina paraque a tesina a roco
# cem um
#
#  43s (160 0%) 2.2991]
# Oso ponoca a cécerentede o da o o fossestar momposte, ţrama polascaro na a o fgarelas sasa
# , dos eus
#
#  46s (170 0%) 2.5819]
# Osiila, o suredo ná e de da ava o mam cicpam o se mesca que sesais farse com Mera tuia nam mau coda
# .
#
#  48s (180 0%) 2.1949]
# Ostum o no Astert0
# o vorente
# seliquios caita sese na naram gue de em o qpito e sem a de e es um de e e
#
#  51s (190 0%) 2.4280]
# Os elia a degicmo em nomeno em nina ser coto some. E queMio no csase noVto nadou onlaber cou dam a as,
#
#  54s (200 0%) 2.4971]
# Os̀e bera.
# reshao laigal em coluicar?s do a penhar.
# (untam a ma, tarido guina parta ara soutar. ha dis
#
#  56s (210 0%) 2.1927]
# Os ma ― . sa o es do Cudar um de samar hara deu diqué into nar inos e mem e ― co, cos no bor a rem hu
#
#  59s (220 0%) 2.3746]
# Os Festade enganide coritecé do se vera e ser, poria Sois canheria pesa ina de, de Eusto mor pereporo
#
#  2s (230 0%) 2.2839]
# Os Diszo meá mãe ou, partes hão. Sea do aha tovege a que o selaende nuto camer eateva coriḑagara "a
#
#  4s (240 0%) 2.6636]
# Os parar ficedes e elermaco conde coscrão merturad. A estabre climê eria com pom de.
# Sou mar foresse
#
#  7s (250 0%) 2.3981]
# Os em rasa ou. se peselavomiras couto có nacoto seberguone de eu um que sa os mina pora rébra, que n
#
#  10s (260 0%) 2.2401]
# Os peretar, mora selhente e de endo e e pentica tintro e mfito de nas listada Cacaperxo e corda ue e c
#
#  12s (270 0%) 2.3425]
# Oslo e a ebrere que mom noças em depara seê. E sal no. ure o deca pora de veis com ambito e secem a b
#
#  15s (280 0%) 2.3158]
# Os os o O serelra, Hido, a tomo ques des.reciado permado as ecencos solinhas parechabireça? pevonpobi
#
#  18s (290 0%) 2.3956]
# Os ana ser abríatimos., Fame. uma seu exipão que a girá esides elintoí Vome, Sor. Varia Múlaria d
#
#  20s (300 0%) 1.9409]
# Os ãino e mentor de oupos morto sesta mei o, do" Jocertpo que e usico o comem palose que dau gudova pa
#
#  23s (310 0%) 2.1372]
# Os pareis da boli de sarenhande maressal emante moze, O do Mucnão. ― o horirem e mentol avader. E era
#
#  25s (320 0%) 2.1255]
# Os a nada tla nas etou com para décivoce, e ticido eo, dido do do de tro e astivio e meito que o ne p
#
#  28s (330 0%) 2.3021]
# Os gardo.
# ― pelo. Fer o para ponfespaveira ame lpar par nque fido pedoceis dos da dre pralita, deporin
#
#  31s (340 0%) 2.1160]
# Os erirez na da e peniando
# ― icomo na supara fóiriando rescispó um pedo pariima Tano ostecando e Isc
#
#  34s (350 0%) 2.1997]
# Os o no e no marro se mopo. Vitar com que pé Márelo merta cansado que ela de vê a nha tavodo ma e m
#
#  36s (360 0%) 2.1759]
# Os,.
# ― Nos asse tano versando eura asprerao éla Envencalta cansanco, titenos do rompagas pára ceruda
#
#  39s (370 0%) 2.2795]
# Os e grespam
# um bom resso convisua da o com habar. Endo Bine, se na aste. Eis sugar ebrissê a sa não
#
#  42s (380 0%) 2.1419]
# Os o do veiza motresia. ― mindo para na retoras a em a da coms a da tentima da e pinar, a ana de uçis
#
#  44s (390 0%) 2.0424]
# Os Tatão porsa parcaria qua compreaviu?
# ANissacia ma rela foora..
# caitadou. Se anher vater as dimado
#
#  47s (400 0%) 2.2558]
# Os seu dada no tacos não quelia nado da encateranco nesmas e cana no ditos secem da esse chesto de pa
#
#  49s (410 0%) 2.1723]
# Os ponjez com em nunha
# prem um sia pretar de umia-do des cara a cona do pria sesser, fuma não enhenve
#
#  52s (420 0%) 2.1582]
# Os fovostélio. ― E do era Comeri, ul é abrento comos moma Duico ele no pracera no vero poi Irma o eli
#
#  55s (430 0%) 2.1996]
# Os gasma nom imhos aras nõo com o ela pormo colãosso ligos, am-nos priscos que e chava vinacó o teus
#
#  57s (440 0%) 2.0716]
# Os seãa a ou preca de esse felanesgura da canha nava apara amel por aprades mepossam ergão um seindo
#
#  0s (450 0%) 1.9928]
# Os "Parão da abando dra prideger fite. Sece cameida de dei a as monte portino e um e a numa veice conf
#
#  3s (460 0%) 2.0650]
# Os sásso doisso de o não.
# Por a sim zrindo, ouranto de forradacal pissaspor de podo o dos entando ens
#
#  5s (470 0%) 2.2813]
# Os paras na por e cosdo sem peres. A domes nespar e o sobinado, deise tisuavesse entuente. ― A cocreç
#
#  8s (480 0%) 2.1905]
# Os comentua. Voi garco. Mar da métino na nupraina de vifaras a dem na e persanho se inama fradesguna
#
#  11s (490 0%) 2.1881]
# Os Porgo com o atão o de postremecido dua pama em no em tum de como meis se Sua sé tata, a no idida
#
#  13s (500 1%) 2.0139]
# Os pera não as suara fitário de se vais, nura tador de tez ber oum que as de dimentiE tera salica mo
#
#  16s (510 1%) 2.4278]
# Os para a mentes e tuonho os não o o seu se suava seure as pera?
# ― ― ― Ass nhãos tês Eral. Minha do
#
#  18s (520 1%) 1.8784]
# Os lonter. No ver fentuchas a brá vorçoma no estalu? Cocentes ou damão uma seu? O no Mada que não
#
#  21s (530 1%) 1.9729]
# Os Selandelida abina ums gfegra na macinha não o porm cassacou por num ária de compreitura sua perti
#
#  24s (540 1%) 2.0952]
# Os neu vem um trapecês. Denfeŗar des fondo era milhada.
# ― No cótívera para verio?
# ― as nado comina
#
#  26s (550 1%) 2.0076]
# Os nos no mado da daima gome quilnho faria ascKiz.
# Diusiz do moja viz de de upêI com não as por devir
#
#  29s (560 1%) 2.0719]
# Os amorgeros diovao dopo de cuência.
# ― Na um o aninho que cá indo sutas, costesto vogo, as code loce
#
#  32s (570 1%) 2.1164]
# Os mum mariabo.
# ― Éu lostar bos por dios, de té vou qse que Peu sesfeá reu mals para um malão exand
#
#  34s (580 1%) 2.4358]
# Os êssente os quem no seu qua a condesĩe cós a se sei muito, parara. E ou cada o astinar uma dice? P
#
#  37s (590 1%) 1.9140]
# Os como tergo era e encasarenta o a a fovia. Estas mizvio, que ele que Tartanente, eva cemome mente ou
#
#  39s (600 1%) 1.9962]
# Os, resilou nu..
# Porsa. Ma elinava do liza conhuito. Que denho, não dou sem fursade o Pre luímo ence
#
#  42s (610 1%) 2.1516]
# Os pou pira insial de os dessos meiso e perinho, um lar é pritele que de eque a era preira o que as m
#
#  45s (620 1%) 2.0733]
# Os de baram e que a tranho, fosvito, eleu sotentar do voça "umáver calera. Exgas a que bora eu telha
#
#  47s (630 1%) 1.7541]
# Os sé e a conte. Nãove sida, da hoatá sobra dia "́nggade de fibre de cratinhe do fil. Pala noutra.
#
#  50s (640 1%) 1.9554]
# Os sorans estonando.
# — E dicasina da tergo o icocive faros eu mobro com estítera, asulhois. Estas gle
#
#  53s (650 1%) 2.1901]
# Os esma não máis! ― Manha e quera nó. Do umara de pralhal...
#
# ― Vaspos a trantes era o mai de rais
#
#  56s (660 1%) 1.8829]
# Os tinha o conssa priógi porcho O afogrispou pide, parros e requal.
# Pazer de munsto o as não o outro
#
#  58s (670 1%) 2.0765]
# Os do nos liu com a dasso, que os ceraito de no meferdadudamam praseco messe lescimaçaçada o devocon
#
#  1s (680 1%) 2.0302]
# Ose mau num preira e meu seu sera na merapê. Deilame
# tida déprecio nada com tem sera espeios. O nem
#
#  3s (690 1%) 2.0676]
# Os os elão sui mazar dele tenprestelenta com o midier de mundo devero todo restudo com para prigário
#
#  6s (700 1%) 1.9245]
# Os uma Hurtido, que que ela o Poriia nintar no o pore fasso sabelet, podes em forlianido diz dia janci
#
#  9s (710 1%) 1.9428]
# Os não nosso pressaer com na uma nada vida não le se Soessade de o sei branha, com o sa?
# Não de pre
#
#  11s (720 1%) 1.8178]
# Os pecorem té arrasta prantera sesbraralço, no fai polhor alcomem ao essíria. Sebelesse ela pai o co
#
#  14s (730 1%) 1.8661]
# Os seu folem ívios. O é porma ina se dem mavar ou que o quente eu (ação no ó os pralo entico, o qu
#
#  16s (740 1%) 2.2807]
# Os atincia seu com jutanva. O que disse a que ficestra pasta que frante sor para que ano na hão pritã
#
#  19s (750 1%) 2.1785]
# Os uma vasia compo.. Ela que estera e conheresa no vem do umama peser numa minha pricurgande eumo tors
#
#  22s (760 1%) 2.0138]
# Os quabém que inacarreçazente tinhona, sonso entrande deisa.
# Pridecera. Olelica.
# O numenile de tero?
#
#  24s (770 1%) 1.9087]
# Os Faria vescerras com o cara sé or a Nalta de passa enhera paados e o como o chula ca— depacho de ou
#
#  27s (780 1%) 1.8020]
# Os compais e que tima checentes e antelho, tem comsil é chomo do pricapos era desas mais do mavando o
#
#  29s (790 1%) 2.0257]
# Os conncilate paro e vopencialdos omam, do não. Pas de se nomes que mas gondos?
# As civê comas tem em
#
#  32s (800 1%) 1.9967]
# Os e procor conferdo de cara um suas em o consimbros nos da Bezos se casos, que no estaras a aberros.
#
#
#  35s (810 1%) 1.8528]
# Os. não de cadosso essa contua do Mão meninha muito diga.
# Estar jas que que que hambossentes os Cume
#
#  37s (820 1%) 2.0050]
# Os
# Vado cotavados polhe Fancia fumenta.
# ― Nós, pura de livor do mas nomem feche muisto entro aceira o
#
#  40s (830 1%) 1.8357]
# Os mara do tla que uma não conta chado a cara para soi. Por tos tuca.
# ― O dizeria sanesmo. Duir memo.
#
#  42s (840 1%) 2.0123]
# Os contermentes diz
# ― Té estis do meu verinha de Bradia o de aquem. Panco como as com aquinte as mais
#
#  45s (850 1%) 1.8583]
# Os numa pormamos do de a 2rminha menho se empressonendo alguanda no fo3 a nossa pesmo o carmada parara
#
#  48s (860 1%) 2.0710]
# Os um grargia coma. dmuitravia a se unte, manha de se o as ponos osro?
# ― O briovet que umo para a.
# Tom
#
#  50s (870 1%) 2.1262]
# Os que não que sobor o um nossa sodenio. O helheus o balado veca Um chavem coluca. Ua teguébia. Seu
#
#  53s (880 1%) 2.0318]
# Os de como e a casanco Luite que mumo e como de baminte estaria com no que no se mas, como sobre o mur
#
#  55s (890 1%) 1.9486]
# Os o pressos depois do procuito receiras por por chumam cerpos Carpos mainhão, e tem ilicheito.
# O té
#
#  58s (900 1%) 1.8465]
# Os com um clarar postá de para home rasser algo forda sou que eu o quele como coma (uta parcara de es
#
#  1s (910 1%) 1.9818]
# Os possa am polta que degando a Estei pessa asxo o precídiado em a se tempre escerião uma da seguím
#
#  3s (920 1%) 2.3417]
# Os que teis para e meu infite, e o seu suantou comé desperide como no enteria fozal pode por um a unt
#
#  6s (930 1%) 2.0237]
# Os galher as trampo conher vido a sacêm podia a maporcer e a seu bolis para fizamente tem esta maguan
#
#  8s (940 1%) 1.9405]
# Os estado se a com o bem a para dos bom pasta no, pois num a mitada não se comido, é dorros seisso,
#
#  11s (950 1%) 2.0472]
# Os dena contremscidamos qui estava filanos que toda exatando errassas cara. Vocissem destá diraça, u
#
#  14s (960 1%) 2.0452]
# Os exela que etas dem quamente...
# ― O cincico. Ela priga deso sua tra, do foz. Vamum e mor no messo o
#
#  16s (970 1%) 1.9107]
# Os da Monnava deveguirás. que a retalbe, não o fiz, que sen cal. Se que tem do mesma" camo.
# ― Hulhe s
#
#  19s (980 1%) 1.7624]
# Os de menha não cocolas de farrante?
# ― Por subrir e ariserando as com conpêncio que de para mesem de
#
#  22s (990 1%) 1.9014]
# Os e outro a quartilina jeica em poro Moi do Minte que nundina na contava ele e tém e fazina tília a
#
#  24s (1000 2%) 1.9371]
# Os denar entrece, estava da Pora dia à ditigado e padegaregelinata.
# Ele a megando do susiores cavando
#
#  27s (1010 2%) 2.3832]
# Os com com o vitura.
# Eu se conté me os momem como Mós sente grante não na aé. O mé estão de Lore
#
#  29s (1020 2%) 1.8014]
# Ossa não pararar. Aémia
# Algranto do Mrenciossas. Tando. Armonas era Routro? A guá estava mas veráu
#
#  32s (1030 2%) 2.4058]
# Os Juirra! O vez samer a um seu demeça que lendo téria a o param não. Maminha me diz que Calar, mes
#
#  35s (1040 2%) 1.7974]
# Os com, atrecum sua porsia. Elim a Fim pais do seira. ― Mas ser anos. Espois num umbando. ― Péria do s
#
#  37s (1050 2%) 2.1781]
# Os mas ra esta. Comento de termam na cama do fagos do essogrançada var caminta-" esteras chamentis av
#
#  40s (1060 2%) 2.1035]
# Os enistímelo pedisho e prospe. A linha que as desherso de tema toles pala se contou praras não esco
#
#  42s (1070 2%) 1.9026]
# Os tragera de recioleum peleger o Arrotar da orginha uma a vois não exvassor as fulher a separidou em
#
#  45s (1080 2%) 1.8970]
# Os denortas ela pé, de sergubando Reressa estava e um canada. ― Como amamenta té para outres e a bal
#
#  47s (1090 2%) 1.9605]
# Os dotxo que ara goranção do Pá maiso e não estrasiava tura serina da tícia da meu nome é disse u
#
#  50s (1100 2%) 1.6725]
# Os amrasiá este racesta, que com comeira que quei estam de para feva e persa serros e os seu a luenci
#
#  52s (1110 2%) 1.8141]
# Os, acha Alherabia corm a minão em altalmenta da aminizar inha com ós colham.
# Ele tifero meios tramp
#
#  55s (1120 2%) 1.6729]
# Os os perto?.
# ― ― O fiz o Teieria não do marseu de um preciio de Mermada imida numo comece sem de o b
#
#  58s (1130 2%) 1.8189]
# Os torrando de instesso um cada se cossu inde ele a merradas para e o conde que paar liá" e a um meit
#
#  0s (1140 2%) 2.4614]
# Os fito em lem e encê eu fizer ― ê não da nos a sua velha está a belhinha de massovo. Perino que e
#
#  3s (1150 2%) 1.9013]
# Os e o quante apração..
# Uma desse não a seguinto seu desma o suestado.
# ― Piria bote-so. Quem Chime"
#
#  5s (1160 2%) 1.8532]
# Os prasia assa sou fara cabia o seu os munta firar cenda viz com como melhas na para serida seu e a pe
#
#  8s (1170 2%) 1.9461]
# Os em falado. Torma, conhegou que o tinham. Ano mesmo depois não titão. Não jogou. O perqueses e pr
#
#  10s (1180 2%) 1.7549]
# Os estre e é me tonha baço radiz Sem se gara Barício inconta. Não cá ele lem o Sitou na megor a m
#
#  13s (1190 2%) 1.8467]
# Os morado da muito. Que se com que quafinar me ánica o derada tação a mular cavam a as anitação p
#
#  15s (1200 2%) 1.8776]
# Os fora de outro a mesmo bem mas curco. Amal. E deperemos na chidava. Se o fado. O huma compo e com pr
#
#  18s (1210 2%) 1.9678]
# Os de peleves.. Para uma depecestado. Não estemos mulheresos não estavoa dulha escuter. Voz, Magos d
#
#  21s (1220 2%) 2.0092]
# Os movida que ous ele pador enfretés ester se estação de faja sóvia de o culher o todo o enfira pal
#
#  23s (1230 2%) 1.8222]
# Os persorida. O ombrem a para pai que de rinicdados de casara e sembra de claméira e a Bicabiamente a
#
#  26s (1240 2%) 1.8471]
# Os homem vertada na musar cifila.
# QaQué na quale a tempo atem proca. Não do aquivor mas entre entre
#
#  28s (1250 2%) 2.0438]
# Os tando desespaciso, pela não seiu. E interxal e o que ele trousa se altíniniava o um acho. Eu lád
#
#  31s (1260 2%) 1.9108]
# Os não.
# Nado de cavrálas. — Resmo de como caras trada a vivrando verdro era voser no trada entru abi
#
#  34s (1270 2%) 1.6868]
# Os blava a hora de Nundo exouco capara, do um cometo como ateriam tedo o bem com começaia de um came,
#
#  36s (1280 2%) 1.6930]
# Os horramal, de a terros bonto, lava o gentar a mupau as noita. E comentra é no f nove o sua penfo ra
#
#  39s (1290 2%) 1.9594]
# Os hisha contela diz.
# O outra, com a me o Jorá uma Elenão se greberdou e o crefência ópio.
# A Acal
#
#  41s (1300 2%) 1.9135]
# Os seguíns bosse o penscas. Para que é a nonima que a masse da dessonada a que deira a uma sera foi
#
#  44s (1310 2%) 1.9359]
# Os ecar previa-quer. Mas sá veria forme, que daixa. Alivenecianto dinizer com de que fulher, que eu a
#
#  47s (1320 2%) 1.9366]
# Os sogrou só poeto mesmícia o contegau da ser. Marga que neve que funca que a estava na ausmos. Nuga
#
#  49s (1330 2%) 2.2937]
# Os em sazento. Não etassistaram a ser Borata nome a meu ou dianisciando de comem, sem ele entradodos,
#
#  52s (1340 2%) 1.9930]
# Os melimos do bé seu sair a nuto ou úlhito que a tominho e vizinha pei de que estibéias. Masse o sej
#
#  54s (1350 2%) 1.8706]
# Os que um pescondivia quanto a uma mesmo seu um entete tento. Mar o Candecia. As que não gury Frinumur
#
#  57s (1360 2%) 1.7581]
# Os escara presama da prontido. O etro?
# ― Não a bocendo. O Gonténcia, acomenta.
# ― Locê mação é qu
#
#  59s (1370 2%) 1.8229]
# Os de que cidonos contra de encontro tém mor, mai que meu o concê? Eu bala em que sem noite dem vito
#
#  2s (1380 2%) 1.7479]
# Os trante acossaço foi posso para para atada se massem. E eu que a colheira se dia podesse escrinspos
#
#  4s (1390 2%) 2.1299]
# Os atendo o Andiar gamou.
# "Pregasa fiza as jundo.
# Sem contrarte que é invecondo.
# ― zinho Ardém as Ma
#
#  7s (1400 2%) 1.8927]
# Os mesm, os tintimenta.
# A um asseira.
# ― A compresidade em huma esta nasinhão de peisa pode que enterr
#
#  10s (1410 2%) 1.8067]
# Os o que para mundo pera fora neu um como, eu viceira com cenava na fajundo se pente Bana, inde tescó
#
#  12s (1420 2%) 1.8408]
# Os nos Dia que eu as ma.
# ― Meu ora sua nomas na vazinha para o tendor a flalmente que peren. Ele porde
#
#  15s (1430 2%) 1.9841]
# Os gastramentos pela torres como. Não, é tação na vocela, prepossas dusico, é mudos e desintindo
#
#  17s (1440 2%) 2.0362]
# Os devipos, entepon, e e entrada de Leino perturalmente que era codo o vociomente semundo entróricos
#
#  20s (1450 2%) 1.7859]
# Os se totem não quê estando da prongende se brindencia, como tinha depalado, jó a que tinha cergunt
#
#  22s (1460 2%) 1.7761]
# Os desciãa de Atura.
# ―.
# ― O Argego deira. O espê cachema de mulher que foi a terxado telênia farta
#
#  25s (1470 2%) 1.8497]
# Os Brantão que ano, alio afilos dos cartar a calar a prontarde, abria e comporgou que não libeira e
#
#  27s (1480 2%) 1.8846]
# Os pois de fação.
# De mais deis gora entraços. Vocem a cola e ruá a lidente devida de o um, ná aque
#
#  30s (1490 2%) 2.1969]
# Os e o Bradasente, foi o primeiro. E e com o este a cãorando fana, mas atré a com conventer se para t
#
#  32s (1500 3%) 2.0100]
# Os sem amanhas amagalo. Depoida entente fim: no Brati. Mâmlitava com direçar da peláia em pretígia
#
#  35s (1510 3%) 1.8515]
# Os por consitura ― A dexistas mento e anderemes e pespera o os Poscer uma da sua morgunto que pordestá
#
#  38s (1520 3%) 1.7736]
# Os navícia que a tremoria, o é inuma maneiro, tardas tura canos parecia a precicar a terlas e celo e
#
#  40s (1530 3%) 1.7203]
# Os vação é estava telebrado em roybura da Sícia. Gratatatrão se intiligistudasse e a devem a ela
#
#  43s (1540 3%) 1.8405]
# Os temperando eu inquela dizermente com sei o tem dois para é a mólia um os disso da cabeça. O capa
#
#  45s (1550 3%) 2.0297]
# Osundo essobre proçães, no lava filha e: A Tó com depois concura não do os uda em gotou do tem fim
#
#  48s (1560 3%) 1.7749]
# Os preser contala valpo. Ele vip-lo vocêl deram artento do exicicaçou o reanção, jastava com ele a
#
#  50s (1570 3%) 1.8783]
# Os altásse, está que exiciar, na ém voz sabia e degaram nodo entrespeiso da Vistos por que com o vez
#
#  53s (1580 3%) 2.0416]
# Os borácio. Que um distida regundo um vida difissa do que não com de uma ria hidudaria conver um rua
#
#  55s (1590 3%) 1.9388]
# Os entre peciridade e sapridarece de babos da chamada tinha o voi. O menhor de que a que de mas de par
#
#  58s (1600 3%) 2.0109]
# Os eu demeria em controveitão para que eu assanos como que alema soutro nóstos ao camo do sua consem
#
#  1s (1610 3%) 1.9883]
# Os que a trovara não canumar e aprenunçado cama. O mais a gangande disse fima. Mas as o numa paro. A
#
#  3s (1620 3%) 2.0750]
# Os bocinal ingrente de Bontar ou.
# Não se acontava a que a mesendo de Regatole e seu alguma tido ou de
#
#  6s (1630 3%) 1.8676]
# Os destá por na cabê. É antou era sabia? Mas em rai vidrever em de ússida sem fiste. O amarassotado
#
#  8s (1640 3%) 1.8420]
# Os seu apando de que esconteiro de secreso ― Rishamo de a balmarina de estavam do cidassão, na lida.
#
#  11s (1650 3%) 1.7958]
# Os á só meu está una com a insexuração era cididos da como de paredisto do intista, inda uflila te
#
#  13s (1660 3%) 1.9767]
# Os clintaria. Se golatina e depois suas espaté o mavia as caritanto a menha. Hajéio de "Vassa da uma
#
#  16s (1670 3%) 1.6798]
# Os mulhores convelo e anos com era o vez a eu não e dizar mais ser você as sompros a a vez para não
#
#  18s (1680 3%) 1.6411]
# Os prarocência. Por entrou da sua não ifejar a camor. dizer mão o carkeço com cocasa tinha demar br
#
#  21s (1690 3%) 1.9318]
# Os a cara desta de que a matão peros éticas e que frenho de meu palado. Ipassa. Eu exisse uma regand
#
#  23s (1700 3%) 1.8681]
# Os um lempesto destés.
# A Clararmas Ana procuntos uncos. Você sido pez davas forque eu sória para co
#
#  26s (1710 3%) 2.0549]
# Os serres e cóve o pensados o que eu a veitor o disto pana. A bonhei o raneça o cerdado o o porfulvé
#
#  28s (1720 3%) 1.7357]
# Os como para essal a sua mais, goração de prelêpio de atral. Eu frande num finham não para. Ou fol
#
#  31s (1730 3%) 1.7690]
# Os e o é de cosas de cartans me bazendo sobrigo mada, que ele descerdesse fasto: vol a naber tode ser
#
#  33s (1740 3%) 1.7666]
# Os ereculas. Tar um chamada oua o quando pereceisa a nostimo experia compordando esta a tidas do fahor
#
#  36s (1750 3%) 1.7187]
# Os. Eu que vei a falê ura coisa.
# ― Ele nos provum o telbê que nenheja de restando do capassas de oup
#
#  38s (1760 3%) 1.6140]
# Os espém, que compre. Alo você ― vocia era as ulembir o da Rutal paura e o limado aliar e estada a g
#
#  41s (1770 3%) 1.4364]
# Os para outrassas disse ema estavam ― acrevérias, a obres sim" sue mas mas em se é, em esfardir a in
#
#  43s (1780 3%) 1.8634]
# Os de os contronte em combino em não. Não a ter não ela saindas humam destedo, ão desonando?..., c
#
#  46s (1790 3%) 1.8508]
# Os algue sém minha constrivas, memo do proma e para não para secura entrasa altavam não são ser se
#
#  48s (1800 3%) 1.6734]
# Ossim, no ficou que sobre saber era do tem sorro e vratas de ser detro num como que sevistas era do Ri
#
#  51s (1810 3%) 1.7232]
# Os ganha.
# ― Voto do Maneu deu o distomento estado, a sorkem de entrá sem para uma pepaxa.
# ― Suagra em
#
#  53s (1820 3%) 1.6588]
# Os com o hoje teve não com acolando para um casaçada a 2ostro.
# ― Nos cima se ele o fringes mais aind
#
#  56s (1830 3%) 1.8749]
# Os, atestava e para nuda. Sue a bija e para se estutas. Que você a comportaria você o moção. O mas
#
#  59s (1840 3%) 2.1434]
# Os desclanta com o homem de lecido a geranto de um com o Socar.
# Presinladas e se com a quenta é não,
#
#  1s (1850 3%) 1.9923]
# Os estas em mas do reicula. É conterra Não preita. A magente o quante, a colemos tudo as meu oudou e
#
#  4s (1860 3%) 1.7884]
# Os impretes na carte, escrares comita e carecel do hanível é, eu voltou baia, comeio filta se que a
#
#  6s (1870 3%) 1.5972]
# Os ruista da últéria sem depois de seus se sericiam para sempre na fica crincam a ériamos do depois c
#
#  9s (1880 3%) 1.6799]
# Os casamantes estra e os pressensamão morte, é e não fez a quentara concurar dona cama a muntão que
#
#  11s (1890 3%) 1.5583]
# Os, morrá tesformar. Por escolhê a genho na forar posse é o pnosses, musinho. Ele a Húdia, estã s
#
#  14s (1900 3%) 2.1255]
# Os como O vida -
# sincida, parte sem depretível, Alheris. Usao comprete de portimeiros.
# Catermades que
#
#  16s (1910 3%) 1.9585]
# Os casiar pormas e acou diz o paírio, estal mas em casão ao um escontada disse o que a com o mais in
#
#  19s (1920 3%) 1.9460]
# Os, o visto era nassa minha costanta preprestados, a lade, mais se entretende, e que a jas adelenito t
#
#  21s (1930 3%) 1.8479]
# Os com lados nada e das surpeto de estava se cha querrar pelos vocideeio do reviteiro um casa da casa
#
#  24s (1940 3%) 1.8665]
# Os das estad diverminca entaídeis do seu seiro enfretanto. Por a muito, do merios ondirava bara sota
#
#  26s (1950 3%) 1.6551]
# Os preveceu ver lefentenciamos da docidação avá não. Eu que eu o vida sentre reantes para, da sua
#
#  29s (1960 3%) 1.8613]
# Os deculta de anos a cara de contustas embara a disse granta um do brasil, é o basbo eu como bustia d
#
#  31s (1970 3%) 1.8478]
# Os foi uma folo não alinha do um dia os nosso de dia pensaniçaginalizados estados acaponder a memond
#
#  34s (1980 3%) 1.6747]
# Os malin as canhatam o ver frando se expirecrefenar contaciomente no frevima a morrança abendir.
# ― Na
#
#  36s (1990 3%) 1.7459]
# Os anos prescendo de exister compravar para suísicas no com a sua com jorar não tristos.
# ― Querciu d
#
#  39s (2000 4%) 1.9048]
# Os prima o menos de aminada esver os casa estaram em a mais e dapena da sua sua interrencia que certe.
#
#  41s (2010 4%) 1.9725]
# Os pereconaltido de outro.
# ― Entrava, em descontiçõe. Descoltou por no lenoquee era a sua interremel
#
#  44s (2020 4%) 1.8701]
# Os conhecido o horço ― Quando como reviso 1h, estava um caxar, intinguão de ver uma seu acumigado co
#
#  46s (2030 4%) 1.5308]
# Os descente destá com apaberimigar aumaninus presas almão de seu vende, esse soboká no caso de tem
#
#  49s (2040 4%) 1.6476]
# Os lé, o acontecerada de satrivios nos decisassas. Por que tinha suma da reclandos nas são tem cazer
#
#  51s (2050 4%) 1.9089]
# Os, no mãe vicha de cendente o nossado, o Coente tem ser que o parte a manteno seguinha cadado no che
#
#  54s (2060 4%) 1.7655]
# Os a parido da uma que está tentre verte divernatriz do história do ceu depois esclava, e o cripaça
#
#  56s (2070 4%) 2.0035]
# Os ossas mais em escurarmando a dessos um corta da mulher confico por a que Sá descensa ela ser o sin
#
#  59s (2080 4%) 1.5802]
# Os por é. No recuura de sempre o que no cerdo que se é ela fida ficul fígio fistível pelo séxim d
#
#  2s (2090 4%) 1.8149]
# Os estavam sem tem tempo do um nomo tirou não seuvro entra velha.
# Era concuse não encunta.
# Não se f
#
#  4s (2100 4%) 1.7551]
# Os aconta
# Martar.
# ― O Tálet estava em outro mareção:
# ― Eu promins espetidas nevo, de recussages, en
#
#  7s (2110 4%) 1.8404]
# Os mesmo que não racerdadivada fim toma uma fim. um enviair com a bembado. Uma Coito de levente de me
#
#  9s (2120 4%) 1.8576]
# Os manos de um cata porque.
# ― E a lado que ele da baria que entre nos podo do para entrevois de
# Catari
#
#  12s (2130 4%) 1.6726]
# Os nos tabapam selever nosso nades, e conquertu.
# ― Não saído de ãoi de ele ele conta pomem de vessos
#
#  14s (2140 4%) 1.6775]
# Os assava a cabamente.
# ― Ela e áciosa você. O precisa e ele a.
# Mas que ele dação da plative sínci
#
#  17s (2150 4%) 1.8230]
# Os perdior algumar que o que no resporme você nome e comento de um mais brindeiro pode que sinando tr
#
#  19s (2160 4%) 1.8042]
# Os no hocheiros ela "ona uma crianica com desente em morguão, e tinha perício, em está apentes de a
#
#  22s (2170 4%) 1.8738]
# Os está um para do fica não fareu mentina de uma paisa de estando. Descontinuamo na esclicas. De cas
#
#  24s (2180 4%) 1.7772]
# Os em ticos do uma recesmo para interam falancios do mesmo com o seu algual. Estas vicantes com Doce?
#
#  27s (2190 4%) 1.8982]
# Os mauras aíncia desclaura ver que, mas nenção não hocou em denulh com o semanção nos melhor e a
#
#  29s (2200 4%) 1.8467]
# Os costação na basta é lever. Se o que o Brasil do ponstra, não à dondi o seu se elevimente no qu
#
#  32s (2210 4%) 1.8116]
# Os condeceria. O dosse a grente que trave a seu estrutou de meio atende o qualto das tessa descrederia
#
#  34s (2220 4%) 1.7401]
# Os assem você no para conseana, nenconhecê a tela do assá simbora. Não tinha que é e chanica ser c
#
#  37s (2230 4%) 1.6112]
# Os descriver que ciam, deno eu, a entra em anorte a garia já estem ele a bigoniação. Era de mesmomo
#
#  39s (2240 4%) 1.6616]
# Os para do fanica ser sobre e não estava ou precisa em podeira fergimo? A nenhuma outras do gorda de
#
#  42s (2250 4%) 1.6393]
# Os desoculas do deditinha. Um ventou ele, o gente, com a nessa estava a menha cruto e não se da sua b
#
#  44s (2260 4%) 1.7273]
# Os, alão aluma. Era fim, a trinha diginizel o que não cabia o Argente de minhamado. Mas verdade redi
#
#  47s (2270 4%) 2.4617]
# Os sabeir. O bem saber é um pode não vinho, assim dingHando de para cara pontinava, e os Pipocinha,
#
#  49s (2280 4%) 1.8125]
# Os acaso de outra desta ela que não era a judara com. Nã do vingua, a primeito. Você desta um corta
#
#  52s (2290 4%) 2.3013]
# Os do T0brem aquela se dizer de era certo me dussício como Arfeitar por um presidita que ela outra. E
#
#  54s (2300 4%) 1.7019]
# Os de um rependiam e Issão.
# Se a sua irmar não entrou tatos do Nósse em dorte do preser não não a
#
#  57s (2310 4%) 1.6224]
# Os não era para mais ser por só ou que o podenticas. E visado, sempreto se alianimos e as didentem e
#
#  59s (2320 4%) 1.8855]
# Os, você visês, se começo tem afaio do Altor jouto o mendou fuivamento de sempres da ceito à sulas
#
#  2s (2330 4%) 2.0549]
# Os para aprecisa. Ela vicisteja, encortamento avralido mais de termente rescar mas de tempor de podenc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-d62b8d049792> in <module>()
#      19 for epoch in range(1, n_epochs + 1):
#      20     example = random_training_set()
# ---> 21     loss = train(example[0].cuda(),example[1].cuda())
#      22     loss_avg += loss
#      23
#
# <ipython-input-120-948f74a4e9f9> in train(inp, target)
#       8     hidden = [h.cuda() for h in hidden]
#       9     for c in range(chunk_len):
# ---> 10         output, hidden = rnn(inp[c], hidden)
#      11         loss += loss_metric(output, target[c].unsqueeze(0))
#      12
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-114-1c5953bedbd1> in forward(self, input, hidden)
#      13     def forward(self, input, hidden):
#      14         input = self.encoder(input.view(1, -1))
# ---> 15         output, hidden = self.lstm(input.view(1, 1, -1), hidden)
#      16         decoded_output = self.decoder(output.view(1, -1))
#      17         return decoded_output, hidden
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     557             return self.forward_packed(input, hx)
#     558         else:
# --> 559             return self.forward_tensor(input, hx)
#     560
#     561
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     537         unsorted_indices = None
#     538
# --> 539         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     540
#     541         return output, self.permute_hidden(hidden, unsorted_indices)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     520         if batch_sizes is None:
#     521             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 522                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     523         else:
#     524             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %%
# Com a rede treinada, gerar um texto longo

print(evaluate('O psicanalista de', 5500), '\n')
